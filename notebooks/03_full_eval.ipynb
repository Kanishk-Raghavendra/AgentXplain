# %% [markdown]
# # Full Evaluation
# Generate synthetic benchmark data, run benchmark records, and compute metrics summary.

# %%
from pathlib import Path
import sys

root = Path.cwd().resolve().parents[0]
if str(root) not in sys.path:
    sys.path.insert(0, str(root))

from experiments.run_benchmark import run_benchmark
from experiments.eval_metrics import evaluate

# %%
out_path = Path("results/benchmark_results.json")
records = run_benchmark(n=60, seed=42, output_path=out_path, use_mock_router=True)
len(records)

# %%
report = evaluate(records)
report
